# %% [markdown]
# <a href="https://colab.research.google.com/github/arunagapure/arudemo/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import numpy as np


x = ['A', 'B', 'C', 'D', 'E']
y = [10, 20, 30, 40, 50]

plt.bar(x,y, color = "green", linewidth = 5)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('My Plot')
plt.show()

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y, color = "red", linewidth = 2)
plt.scatter(x, y, color = "black")
plt.title('Sine Wave')
plt.xlabel('Sine Wave')
plt.ylabel('Amplitude')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = np.linspace(0, 10, 100)
y = np.cos(x)

plt.plot(x, y, color = "pink" , linewidth = 1)

plt.xlim([0, 10])
plt.ylim([-1, 2])
plt.xlabel('Cosine Wave')
plt.ylabel('Amplitude')
plt.title('Cosine Curve')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data = [('2022-01-01', 10.1),
        ('2022-01-02', 8.9),
        ('2022-01-03', 6.3),
        ('2022-01-04', 7.2),
        ('2022-01-05', 5.6),
        ('2022-01-06', 4.8),
        ('2022-01-07', 6.5),
        ('2022-01-08', 9.2),
        ('2022-01-09', 11.8),
        ('2022-01-10', 12.6),
        ('2022-01-11', 9.5),
        ('2022-01-12', 8.3)]

# %%
df = pd.DataFrame(data, columns=['date', 'temperature'])
df
# Out:
#           date  temperature
# 0   2022-01-01         10.1
# 1   2022-01-02          8.9
# 2   2022-01-03          6.3
# 3   2022-01-04          7.2
# 4   2022-01-05          5.6
# 5   2022-01-06          4.8
# 6   2022-01-07          6.5
# 7   2022-01-08          9.2
# 8   2022-01-09         11.8
# 9   2022-01-10         12.6
# 10  2022-01-11          9.5
# 11  2022-01-12          8.3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         12 non-null     object
#  1   temperature  12 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 320.0+ bytes

# %%
from datetime import datetime as dt
df.loc[:, 'date'] = pd.to_datetime(df.loc[:, 'date'], format= '%Y-%d-%m')
# Out:
# <ipython-input-8-a3ab904c89e7>:2: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, 'date'] = pd.to_datetime(df.loc[:, 'date'], format= '%Y-%d-%m')

# %%
df
# Out:
#          date  temperature
# 0  2022-01-01         10.1
# 1  2022-02-01          8.9
# 2  2022-03-01          6.3
# 3  2022-04-01          7.2
# 4  2022-05-01          5.6
# 5  2022-06-01          4.8
# 6  2022-07-01          6.5
# 7  2022-08-01          9.2
# 8  2022-09-01         11.8
# 9  2022-10-01         12.6
# 10 2022-11-01          9.5
# 11 2022-12-01          8.3

# %%
plt.plot(df.loc[:, 'date'], df.loc[:, 'temperature'], color='blue', linewidth=2)
plt.xlabel('Date')
plt.ylabel('Temprature (°C)')
plt.title('Temperature Over Time')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data = tips, x = 'total_bill', y= "tip", hue="day", size="size")
plt.title("Tips by Total Bill and Smoker Status")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data = np.random.normal(size=(100,))

fig, ax = plt.subplots()
ax.boxplot(data)
ax.set_title('Box Plot')
plt.show()

# %%
data = np.random.normal(size=(100,))

# Create a box plot
fig, ax = plt.subplots()
ax.boxplot(data)
ax.set_title('Box plot')
plt.show()

# %%
data = np.random.normal(size=(100,))

fig, ax = plt.subplots()
ax.boxplot(data)
ax.set_title('Box Plot')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Given Data
tips_data = [
    (16.99, 1.01, 'Female','Mon', 'Dinner', 2),
    (10.34, 1.66, 'Male','Mon', 'Dinner', 3),
    (21.01, 3.5, 'Male', 'Tue', 'Dinner', 3),
    (23.68, 3.31, 'Male', 'Tue', 'Dinner', 2),
    (24.59, 3.61, 'Female','Tue', 'Dinner', 4),
    (25.29, 4.71, 'Male', 'Wed', 'Dinner', 4),
    (8.77, 2.0, 'Male','Thu', 'Dinner', 2),
    (26.88, 3.12, 'Male','Thu', 'Dinner', 4),
    (15.04, 1.96, 'Male','Sun', 'Dinner', 2),
    (14.78, 3.23, 'Male','Sun', 'Dinner', 2)
]

# %%
tips_df = pd.DataFrame(tips_data, columns=['total_bill', 'tip', 'sex', 'day','time', 'size'])
tips_df
# Out:
#    total_bill   tip     sex  day    time  size
# 0       16.99  1.01  Female  Mon  Dinner     2
# 1       10.34  1.66    Male  Mon  Dinner     3
# 2       21.01  3.50    Male  Tue  Dinner     3
# 3       23.68  3.31    Male  Tue  Dinner     2
# 4       24.59  3.61  Female  Tue  Dinner     4
# 5       25.29  4.71    Male  Wed  Dinner     4
# 6        8.77  2.00    Male  Thu  Dinner     2
# 7       26.88  3.12    Male  Thu  Dinner     4
# 8       15.04  1.96    Male  Sun  Dinner     2
# 9       14.78  3.23    Male  Sun  Dinner     2

# %%
df = tips_df.groupby('day')['tip'].mean().reset_index()
df
# Out:
#    day       tip
# 0  Mon  1.335000
# 1  Sun  2.595000
# 2  Thu  2.560000
# 3  Tue  3.473333
# 4  Wed  4.710000

# %%
x = df.loc[:, 'day']
y = df.loc[:, 'tip']
plt.bar(x,y)
plt.title('Average Tip Vs Days')
plt.xlabel('Day')
plt.ylabel('Avg Tips')
plt.show()

# %%
sns.barplot(x=tips_df['day'], y=tips_df['tip'], estimator='mean' )
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
 sns.lineplot(data=tips, x="total_bill", y= "tip", hue= "sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.histplot(data=tips, x="total_bill",  kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
iris = sns.load_dataset("iris")

iris.head()
sns.pairplot(data=iris, hue="species")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.heatmap(data=iris.corr(), annot=True, cmap="coolwarm")
# Out:
# <ipython-input-25-9dbfe73cc835>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=iris.corr(), annot=True, cmap="coolwarm")
# <Axes: >

# %%
tips = sns.load_dataset("tips")
sns.boxplot(data=tips, x = "day", y= "total_bill", hue="sex")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.swarmplot(data= tips, x = "day", y= "total_bill", hue="sex")
sns.scatterplot
# Out:
# <function seaborn.relational.scatterplot(data=None, *, x=None, y=None, hue=None, size=None, style=None, palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, markers=True, style_order=None, legend='auto', ax=None, **kwargs)>

# %%
titanic_data = [
    (1, "male", 22.0, 1, 0, 7.25, "Third", "S", "Survived"),
    (2, "female", 38.0, 1, 0, 71.2833, "First", "C", "Survived"),
    (3, "female", 26.0, 0, 0, 7.925, "Third", "S", "Died"),
    (4, "female", 35.0, 1, 0, 53.1, "First", "S", "Survived"),
    (5, "male", 35.0, 0, 0, 8.05, "Third", "S", "Died"),
    (6, "male", None, 0, 0, 18.4583, "Third", "Q", "Died"),
    (7, "male", 54.0, 0, 0, 51.8625, "First", "S", "Died"),
    (8, "male", 2.0, 3, 1, 21.075, "Second", "S", "Survived"),
    (9, "female", 27.0, 0, 2, 11.1333, "Third", "S", "Survived"),
    (10, "female", 14.0, 1, 0, 30.0708, "Second", "C", "Survived"),

]

# %%
titanic_data.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-4e6907de06e7> in <cell line: 1>()
# ----> 1 titanic_data.columns
#
# AttributeError: 'list' object has no attribute 'columns'

# %%
titanic_df = pd.DataFrame(titanic_data, columns=["PassengerId", "Sex", "Age", "SibSp","Parch", "Fare", "Class", "Embarked", "Survived"])
titanic_df.head()
# Out:
#    PassengerId     Sex   Age  SibSp  Parch     Fare  Class Embarked  Survived
# 0            1    male  22.0      1      0   7.2500  Third        S  Survived
# 1            2  female  38.0      1      0  71.2833  First        C  Survived
# 2            3  female  26.0      0      0   7.9250  Third        S      Died
# 3            4  female  35.0      1      0  53.1000  First        S  Survived
# 4            5    male  35.0      0      0   8.0500  Third        S      Died

# %%
sns.boxplot(data=titanic_df, y= "Fare", x= "Class", orient="v")
plt.title("Fare Distruibution")
plt.show()

# %%
sns.heatmap(data=titanic_df.corr(), annot=True, )
plt.title("Fare Distribution")
plt.show
# Out:
# <ipython-input-45-82db5dbb5b01>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=titanic_df.corr(), annot=True, )
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt

# %%
x = ['Apples', 'Bananas', 'Oranges']
y = [15, 20, 25]

plt.pie(y, labels=x)
plt.title('Pie Chart')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np

# %%
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

fig, axs = plt.subplots(2, 1, figsize=(5,5), sharex = True)

axs[0].plot(x, y1, color= 'blue')
axs[0].set_title('Sine Wave')
axs[1].plot(x, y2, color= 'red')
axs[1].set_title('Cosine Wave ')

fig.text(0.5, 0.04, 'X', ha = 'center')
fig.text(0.04, 0.5, 'Y', va = 'center', rotation = 'vertical')
fig.subplots_adjust(hspace = 0.5)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
